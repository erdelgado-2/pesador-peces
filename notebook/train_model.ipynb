# %% [markdown]
# # Modelo de predicción de pesos de peces a partir de medidas anatomicas

# %% [markdown]
# Preparar ambiente

# %%
import numpy as np
import pandas as pd
from abc import ABC, abstractmethod
from sklearn.base import clone
from sklearn.linear_model import Lasso
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, PolynomialFeatures
from sklearn.model_selection import train_test_split, KFold, LeaveOneOut, StratifiedKFold, cross_val_score
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
import optuna
from optuna.samplers import TPESampler

# %%
from pathlib import Path
import joblib
import time
import sklearn
import platform
import json
import os

# %%
class PipelineOptimizer:
    """Clase de contexto que utiliza el patrón estrategia"""

    def __init__(self, pipeline, X, y):
        self.pipeline = pipeline
        self.X = X
        self.y = y

    def optimize(self, strategy, param_definitions):
        """
        Parametros:
        ----------
            strategy: Estrategia de optimización
            param_definitions: Para GridSearch: diccionario de parámetros
                            Para Optuna: función que toma un trial y devuelve parámetros
        """
        return strategy.optimize(
            pipeline=self.pipeline,
            X=self.X,
            y=self.y,
            param_definitions=param_definitions,
        )

class OptimizationStrategy(ABC):
    """Clase base abstracta para estrategias de optimización"""

    @abstractmethod
    def optimize(self, pipeline, X, y, param_definitions):
        pass


class OptunaSearchStrategy(OptimizationStrategy):
    """Estrategia de Optuna"""

    def __init__(self, n_trials=100, cv=5, scoring="accuracy", direction="maximize", n_jobs = -1, sampler = TPESampler()):
        self.n_trials = n_trials
        self.cv = cv
        self.scoring = scoring
        self.direction = direction
        self.sampler = sampler
        self.n_jobs = n_jobs

    def optimize(self, pipeline, X, y, param_definitions):
        def objective(trial):
            # Obtener parámetros usando la función proporcionada por el usuario
            params = param_definitions(trial)
            pipeline_clone = clone(pipeline)
            pipeline_clone.set_params(**params)
            return cross_val_score(
                pipeline_clone, X, y, cv=self.cv, scoring=self.scoring, n_jobs = self.n_jobs
            ).mean()

        sampler=TPESampler(seed = 42)
        study = optuna.create_study(sampler = self.sampler, direction=self.direction)
        study.optimize(objective, n_trials=self.n_trials, n_jobs=self.n_jobs)

        return study

# %%
RANDOM_STATE = int(os.getenv("MODEL_RANDOM_STATE",42))
ARTIFACTS_DIR = Path(os.getenv("ARTIFACTS_DIR", "./"))

# %% [markdown]
# Cargar datos y entrenar modelo

# %%
df = pd.read_csv('../src/Fish.csv')

# %%
# Separar características y variable objetivo
X = df.drop('Weight', axis=1)
y = df[['Weight']]

# %%
# Dividir en conjunto de entrenamiento y prueba (70/30)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=RANDOM_STATE)

# %%
# Identificar columnas numéricas y categóricas
numeric_cols = X_train.select_dtypes(include=['float64', 'int64']).columns
categorical_cols = X_train.select_dtypes(include=['category', 'object']).columns

# %%
# Escalar y
y_scaler = StandardScaler()
y_train_sc = y_scaler.fit_transform(y_train)
y_test_sc = y_scaler.transform(y_test)

# %% [markdown]
# Aplicamos preprocesamiento.
# Fijamos el grado del polinomio en 3. Grado 3 tiene sentido físico ya que corresponde a una medida de volumén.

# %%
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('poly', PolynomialFeatures(include_bias=False, degree=3)),
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
])

# Combinar transformadores en un preprocesador
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_cols),
        ('cat', categorical_transformer, categorical_cols)
    ])

Lassu = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', Lasso(fit_intercept=True, max_iter = 10000, random_state=RANDOM_STATE))
])

# %% [markdown]
# Ajustamos modelos con optimización de hiperparametros

# %%
def LR_params(trial):
    return {
        'model__alpha': trial.suggest_float('model__alpha', 10**-2, 10**2),
    }

# %%
# Definir optimizador usando la clase y splits de cross validation
sampler = TPESampler(seed=RANDOM_STATE)
optimizerL = PipelineOptimizer(Lassu, X_train, y_train_sc)
cv = KFold(n_splits = 5)
studyL = optimizerL.optimize(
      strategy=OptunaSearchStrategy(n_trials=200, cv = cv, scoring = 'r2', n_jobs=1, sampler=sampler),
      param_definitions=LR_params)
# Out:
# [I 2025-09-28 16:41:35,785] A new study created in memory with name: no-name-bd001e2b-7011-4f30-abd8-4227cc4bf7b2
# [I 2025-09-28 16:41:36,146] Trial 0 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 37.46026648354777}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:36,214] Trial 1 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 95.07192349792751}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:36,285] Trial 2 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 73.2020742417224}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:36,359] Trial 3 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 59.86986183486169}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:36,430] Trial 4 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 15.610303857839227}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:36,497] Trial 5 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 15.607892088416902}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:36,562] Trial 6 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 5.817780380698264}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:36,636] Trial 7 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 86.61895281603577}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:36,712] Trial 8 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 60.115490024203446}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:36,777] Trial 9 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 70.81017705382659}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:36,889] Trial 10 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 37.45391824067213}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:36,967] Trial 11 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 39.00794318065214}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:37,062] Trial 12 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 96.95401570767868}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:37,130] Trial 13 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 34.69162063174811}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:37,198] Trial 14 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 49.69095243288002}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:37,268] Trial 15 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 85.99731014163042}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:37,350] Trial 16 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 25.55179144193223}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:37,423] Trial 17 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 51.30494077841172}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:37,496] Trial 18 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 74.46864333607905}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:37,568] Trial 19 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 99.57960455191139}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:37,641] Trial 20 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 28.08328781442801}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:37,721] Trial 21 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 77.06705084331719}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:37,793] Trial 22 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 91.81639713583955}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:37,867] Trial 23 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 65.75809077931618}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:37,941] Trial 24 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 81.54560499543477}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:38,015] Trial 25 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 50.04870485049271}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:38,088] Trial 26 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 91.5614475037759}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:38,163] Trial 27 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 66.51428206880837}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:38,236] Trial 28 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 55.94177117480068}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:38,311] Trial 29 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 43.97670534726716}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:38,390] Trial 30 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 80.74341911634437}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:38,465] Trial 31 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 62.50150923343598}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:38,535] Trial 32 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 71.03880302433487}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:38,606] Trial 33 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 25.134499329889223}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:38,687] Trial 34 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 10.879811037189796}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:38,773] Trial 35 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 56.3541067599381}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:38,847] Trial 36 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 44.37480148079395}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:38,920] Trial 37 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 58.15420165001794}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:38,992] Trial 38 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 17.12867780877606}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:39,064] Trial 39 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 2.2044303579899207}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:39,136] Trial 40 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 33.39216257091682}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:39,208] Trial 41 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 18.515022107750923}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:39,281] Trial 42 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 11.097903040005782}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:39,363] Trial 43 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 41.87454493850201}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:39,466] Trial 44 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 92.93917502731244}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:39,542] Trial 45 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 31.01062233828908}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:39,616] Trial 46 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 84.42501102182698}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:39,689] Trial 47 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 70.07311739167486}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:39,771] Trial 48 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 20.509175599859155}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:39,854] Trial 49 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 76.01430671920039}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:39,928] Trial 50 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 37.231700467017134}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:40,007] Trial 51 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 10.078862823510747}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:40,083] Trial 52 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 5.702446436561541}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:40,158] Trial 53 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 23.197135765717334}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:40,234] Trial 54 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 15.23556057673745}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:40,314] Trial 55 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 52.1821431583886}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:40,385] Trial 56 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 64.86089178741128}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:40,458] Trial 57 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 1.2035557715318106}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:40,534] Trial 58 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 30.162033855654563}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:40,609] Trial 59 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 46.970847621113336}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:40,683] Trial 60 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 95.92238496963351}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:40,758] Trial 61 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 6.432009468446104}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:40,845] Trial 62 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 14.171972001335273}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:40,923] Trial 63 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 6.078205218849707}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:40,997] Trial 64 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 79.3917833089249}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:41,073] Trial 65 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 60.52794348214398}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:41,154] Trial 66 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 52.66881503397692}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:41,231] Trial 67 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 71.69108652501231}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:41,304] Trial 68 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 88.24249076404377}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:41,404] Trial 69 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 21.884054356531415}. Best is trial 0 with value: -0.04144236768182341.
# [I 2025-09-28 16:41:41,479] Trial 70 finished with value: -0.04144236768182341 and parameters: {'model__alpha':
finished with value: -0.04144236768182341 and parameters: {'model__alpha': 4.538904393773562}. Best is trial 155 with value: 0.9715038036463539.
# [I 2025-09-28 16:41:49,794] Trial 174 finished with value: 0.9674464807757825 and parameters: {'model__alpha': 0.02504936543642189}. Best is trial 155 with value: 0.9715038036463539.
# [I 2025-09-28 16:41:49,859] Trial 175 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 6.921649068513672}. Best is trial 155 with value: 0.9715038036463539.
# [I 2025-09-28 16:41:49,926] Trial 176 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 2.4231326531025665}. Best is trial 155 with value: 0.9715038036463539.
# [I 2025-09-28 16:41:49,997] Trial 177 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 2.6642973036930733}. Best is trial 155 with value: 0.9715038036463539.
# [I 2025-09-28 16:41:50,072] Trial 178 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 5.594474146074965}. Best is trial 155 with value: 0.9715038036463539.
# [I 2025-09-28 16:41:50,147] Trial 179 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 3.6998916961340376}. Best is trial 155 with value: 0.9715038036463539.
# [I 2025-09-28 16:41:50,226] Trial 180 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 2.1993603212760484}. Best is trial 155 with value: 0.9715038036463539.
# [I 2025-09-28 16:41:50,335] Trial 181 finished with value: 0.9618251326462974 and parameters: {'model__alpha': 0.07369457292994377}. Best is trial 155 with value: 0.9715038036463539.
# [I 2025-09-28 16:41:50,436] Trial 182 finished with value: 0.9547393981934846 and parameters: {'model__alpha': 0.1185565942269323}. Best is trial 155 with value: 0.9715038036463539.
# [I 2025-09-28 16:41:50,509] Trial 183 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 4.435744488704386}. Best is trial 155 with value: 0.9715038036463539.
# [I 2025-09-28 16:41:50,581] Trial 184 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 2.060733984410498}. Best is trial 155 with value: 0.9715038036463539.
# [I 2025-09-28 16:41:50,673] Trial 185 finished with value: 0.9491936923558434 and parameters: {'model__alpha': 0.14214273055206694}. Best is trial 155 with value: 0.9715038036463539.
# [I 2025-09-28 16:41:50,785] Trial 186 finished with value: 0.9667127708848607 and parameters: {'model__alpha': 0.028053029845085845}. Best is trial 155 with value: 0.9715038036463539.
# [I 2025-09-28 16:41:50,857] Trial 187 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 7.382166575369781}. Best is trial 155 with value: 0.9715038036463539.
# [I 2025-09-28 16:41:50,930] Trial 188 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 2.465553761689091}. Best is trial 155 with value: 0.9715038036463539.
# [I 2025-09-28 16:41:51,003] Trial 189 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 4.751269870135846}. Best is trial 155 with value: 0.9715038036463539.
# [I 2025-09-28 16:41:51,076] Trial 190 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 2.084859600816277}. Best is trial 155 with value: 0.9715038036463539.
# [I 2025-09-28 16:41:51,149] Trial 191 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 2.1132707797816983}. Best is trial 155 with value: 0.9715038036463539.
# [I 2025-09-28 16:41:51,253] Trial 192 finished with value: 0.9540699117739209 and parameters: {'model__alpha': 0.1217518131717501}. Best is trial 155 with value: 0.9715038036463539.
# [I 2025-09-28 16:41:51,340] Trial 193 finished with value: 0.9116486588102564 and parameters: {'model__alpha': 0.24421904510826928}. Best is trial 155 with value: 0.9715038036463539.
# [I 2025-09-28 16:41:51,468] Trial 194 finished with value: 0.9650289884040258 and parameters: {'model__alpha': 0.03517313319932594}. Best is trial 155 with value: 0.9715038036463539.
# [I 2025-09-28 16:41:51,542] Trial 195 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 4.086588932741221}. Best is trial 155 with value: 0.9715038036463539.
# [I 2025-09-28 16:41:51,671] Trial 196 finished with value: 0.9645151293881356 and parameters: {'model__alpha': 0.04062820541515138}. Best is trial 155 with value: 0.9715038036463539.
# [I 2025-09-28 16:41:51,743] Trial 197 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 6.010903718066355}. Best is trial 155 with value: 0.9715038036463539.
# [I 2025-09-28 16:41:51,817] Trial 198 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 3.4638464595374994}. Best is trial 155 with value: 0.9715038036463539.
# [I 2025-09-28 16:41:51,891] Trial 199 finished with value: -0.04144236768182341 and parameters: {'model__alpha': 2.2918448878395044}. Best is trial 155 with value: 0.9715038036463539.

# %%
# Entrenar los mejores hiperparametros usando todos los datos
best_params = studyL.best_params
best_L = clone(Lassu)
best_L.set_params(**best_params)
preprocessor = best_L.named_steps['preprocessor']
preprocessor.set_output(transform='pandas')
best_L.fit(X_train, y_train_sc)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('poly',
#                                                                    PolynomialFeatures(degree=3,
#                                                                                       include_bias=False)),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['Length1', 'Length2', 'Length3', 'Height', 'Width'], dtype='object')),
#                                                  ('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   Index(['Species'], dtype='object'))])),
#                 ('model',
#                  Lasso(alpha=0.011699785816691427, max_iter=10000,
#                        random_state=42))])

# %% [markdown]
# Guardamos el modelo

# %%
manifest = {
    "name": "Lasso-Prediccion-Peso-Fish",
    "created_at": time.strftime("%Y-%m-%d %H:%M:%S"),
    "framework": "scikit-learn",
    "python_version": platform.python_version(),
    "pandas_version": pd.__version__,
    "sklearn_version": sklearn.__version__,
    "optuna_version": optuna.__version__,
    "random_state": RANDOM_STATE,
    "features": list(X.columns),
    "target": "Weight",
    "cv_metric": "r2",
    "cv_best_score": studyL.best_value,
    "cv_best_params": studyL.best_params,
    "test_metrics": best_L.score(X_test,y_test_sc),
}

# %%
ARTIFACTS_DIR.mkdir(exist_ok=True)
manifest_path = ARTIFACTS_DIR / "model_card.json"
with open(manifest_path, "w", encoding="utf-8") as f:
    json.dump(manifest, f, indent=2, ensure_ascii=False)

# %%
model_path = ARTIFACTS_DIR / "model.pkl"
joblib.dump(best_L, model_path)
# Out:
# ['model.pkl']
